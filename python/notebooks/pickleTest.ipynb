# %%
# %load_ext autoreload

# %autoreload 2

import os
import pickle
from env import pickle_path


if os.path.isfile(pickle_path):
    with open(pickle_path, 'rb') as f:
        pickled_data=pickle.load(f)
    print(pickled_data.keys())
    data = pickled_data[list(pickled_data.keys())[0]]
    keys = ['sample_idx', 'gt_names', 'gt_world_box', 'gt_boxes_lidar', 'points',
            'gt_boxes', 'voxels', 'num_points', 'coordinates', 'voxel_centers',
            'click_point', 'train_idx', 'point_sample_idx', 'batch_size', 'orig_points',
            'gt_classes', 'hm', 'anno_box', 'ind', 'classes', 'mask']
#     print(data)
#     for key in keys:

# %%
pkl_path = '/tmp/dump.pkl'

if os.path.isfile(pkl_path):
    with open(pkl_path, 'rb') as f:
        dat = pickle.load(f)
    print(dat)
# Out:
# {'sample_idx': array(['000466'], dtype='<U6'), 'gt_names': array([[['Car']]], dtype='<U3'), 'gt_world_box': array([[22.54999924, 62.63000107,  0.94999999,  5.89      ,  2.42      ,
#          2.98      ,  3.13      ]]), 'gt_boxes_lidar': array([[-0.25800133, -0.9129982 ,  0.94999999,  5.89      ,  2.42      ,
#          2.98      ,  3.13      ]]), 'points': array([[ 0.        ,  1.3610001 ,  5.1380005 ,  4.978     ],
#        [ 0.        ,  1.4300003 ,  4.800003  ,  4.967     ],
#        [ 0.        ,  1.3979988 ,  4.169998  ,  4.944     ],
#        [ 0.        ,  1.6599998 ,  4.415001  ,  4.957     ],
#        [ 0.        ,  2.001999  ,  4.8919983 ,  4.98      ],
#        [ 0.        ,  2.4679985 ,  5.715004  ,  5.017     ],
#        [ 0.        ,  2.2839985 ,  2.623001  ,  4.905     ],
#        [ 0.        ,  1.5240002 ,  0.02300262,  4.801     ],
#        [ 0.        ,  1.698     ,  0.03499985,  4.805     ],
#        [ 0.        ,  2.803999  ,  2.590004  ,  4.913     ],
# ...
